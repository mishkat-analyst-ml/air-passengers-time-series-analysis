# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('AirPassengers.csv')
print(df)
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
df.head(5)
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.tail(5)
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
df.shape
# Out:
# (144, 2)

# %%
df.describe()
# Out:
#        #Passengers
# count   144.000000
# mean    280.298611
# std     119.966317
# min     104.000000
# 25%     180.000000
# 50%     265.500000
# 75%     360.500000
# max     622.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    str
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), str(1)
# memory usage: 2.4 KB

# %%
df['Month']=pd.to_datetime(df['Month'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    datetime64[us]
#  1   #Passengers  144 non-null    int64
# dtypes: datetime64[us](1), int64(1)
# memory usage: 2.4 KB

# %%
df.isnull().sum()
# Out:
# Month          0
# #Passengers    0
# dtype: int64

# %%
df['Month'].plot()
plt.show()

# %%
df.groupby(df['Month'].dt.year)['#Passengers'].sum().plot(kind='bar')
plt.show()

# %%
df['Month']=df.index.month

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   #Passengers  144 non-null    int64
#  1   Month        144 non-null    int32
# dtypes: int32(1), int64(1)
# memory usage: 2.8 KB

# %%
df['Year']=df.index.year
df['Month_Number']=df.index.month
df.head()
# Out:
#             #Passengers  Month  Year  Month_Number
# Month
# 1949-01-01          112      1  1949             1
# 1949-02-01          118      2  1949             2
# 1949-03-01          132      3  1949             3
# 1949-04-01          129      4  1949             4
# 1949-05-01          121      5  1949             5

# %%
df.groupby('Month_Number')['#Passengers'].mean().plot(kind='bar')
plt.show()

# %%
df.head(10)
# Out:
#             #Passengers  Month  Year  Month_Number
# Month
# 1949-01-01          112      1  1949             1
# 1949-02-01          118      2  1949             2
# 1949-03-01          132      3  1949             3
# 1949-04-01          129      4  1949             4
# 1949-05-01          121      5  1949             5
# 1949-06-01          135      6  1949             6
# 1949-07-01          148      7  1949             7
# 1949-08-01          148      8  1949             8
# 1949-09-01          136      9  1949             9
# 1949-10-01          119     10  1949            10
